# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import leakgaurd

# %%
DATASET_PATH = 'titanic.csv'
TARGET_COLUMN = 'Survived'

# %%
run_leakguard(DATASET_PATH, TARGET_COLUMN)
# Out:
# ========== LeakGuard Report ==========
# Dataset shape: (891, 4)
# Duplicates:24
# High Importance Features (Potential Leakage):
# ['Ticket']
# ========== End of Report ==========

# %%
DATASET_PATH = 'house-train.csv'
TARGET_COLUMN = 'SalePrice'
run_leakguard(DATASET_PATH, TARGET_COLUMN)
# Out:
# ========== LeakGuard Report ==========
# Dataset shape: (1460, 81)
# Identifier Risk:
# ['Id']
# ========== End of Report ==========

# %%
DATASET_PATH = "bike-sharing-dataset.csv"
TARGET_COLUMN = "cnt"
run_leakguard(DATASET_PATH, TARGET_COLUMN)
# Out:
# ========== LeakGuard Report ==========
# Dataset shape: (17414, 10)
# Identifier Risk:
# ['timestamp']
# Temporal Leakage Risks:
# - Dataset is sorted by 'timestamp' (Ascending) - Random splits may leak future info
# ========== End of Report ==========

# %%
DATASET_PATH = 'bike-sharing-shuffled.csv'
TARGET_COLUMN = 'cnt'
run_leakguard(DATASET_PATH, TARGET_COLUMN)
# Out:
# timestamp 0.781481963335331 1.0 0.9982771492563027
# LeakGuard Report v{__version__}:
# Dataset shape: (17414, 10)
# Identifier Risk:
# ['timestamp']
# Temporal Leakage Risks:
# - Temporal Leakage Risk in 'timestamp': High Target Autocorrelation (0.78), Regular Time Spacing, High Timestamp Uniqueness. Data appears to be a time-series; use TimeSeriesSplit.
# End of Report.
